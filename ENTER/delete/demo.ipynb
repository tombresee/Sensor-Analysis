# %% [markdown]
# # Human Activity Recognition (97.98 %)

# %% [markdown]
# ## The above accuracy achieved is better than the research paper itself which was based on LSTM but my work includes ANN on the same dataset.

# %% [markdown]
# **Original approach using LSTM -
# Testing Accuracy: 91.652%    ,
# Precision: 91.762%      ,
# Recall: 91.652%     ,
# f1_score: 91.643%
# **

# %% [markdown]
# **My approach using ANN - Testing accuracy(validation): 97.98%  ,  Precision: 95% ,  Recall: 94%  , f1-score: 94% .**

# %%
import numpy as np 
import pandas as pd 
import os
import seaborn as sns
import matplotlib.pyplot as plt
# print(os.listdir("../input"))

# %%
df = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
df.T
# Out:
#                           0         1         2         3         4     \
# tBodyAcc-mean()-X     0.288585  0.278419  0.279653  0.279174  0.276629
# tBodyAcc-mean()-Y    -0.020294 -0.016411 -0.019467 -0.026201  -0.01657
# tBodyAcc-mean()-Z    -0.132905  -0.12352 -0.113462 -0.123283 -0.115362
# tBodyAcc-std()-X     -0.995279 -0.998245  -0.99538 -0.996091 -0.998139
# tBodyAcc-std()-Y     -0.983111   -0.9753 -0.967187 -0.983403 -0.980817
# ...                        ...       ...       ...       ...       ...
# angle(X,gravityMean) -0.841247 -0.844788 -0.848933 -0.848649 -0.847865
# angle(Y,gravityMean)  0.179941  0.180289  0.180637  0.181935  0.185151
# angle(Z,gravityMean) -0.058627 -0.054317 -0.049118 -0.047663 -0.043892
# subject                      1         1         1         1         1
# Activity              STANDING  STANDING  STANDING  STANDING  STANDING
#
#                           5         6         7         8         9     ...  \
# tBodyAcc-mean()-X     0.277199  0.279454  0.277432  0.277293  0.280586  ...
# tBodyAcc-mean()-Y    -0.010098 -0.019641 -0.030488 -0.021751  -0.00996  ...
# tBodyAcc-mean()-Z    -0.105137 -0.110022  -0.12536 -0.120751 -0.106065  ...
# tBodyAcc-std()-X     -0.997335 -0.996921 -0.996559 -0.997328 -0.994803  ...
# tBodyAcc-std()-Y     -0.990487 -0.967186 -0.966728 -0.961245 -0.972758  ...
# ...                        ...       ...       ...       ...       ...  ...
# angle(X,gravityMean) -0.849632  -0.85215 -0.851017 -0.847971 -0.848294  ...
# angle(Y,gravityMean)  0.184823   0.18217  0.183779  0.188982   0.19031  ...
# angle(Z,gravityMean) -0.042126  -0.04301 -0.041976 -0.037364 -0.034417  ...
# subject                      1         1         1         1         1  ...
# Activity              STANDING  STANDING  STANDING  STANDING  STANDING  ...
#
#                                   7342              7343              7344  \
# tBodyAcc-mean()-X             0.276137           0.29423          0.221206
# tBodyAcc-mean()-Y            -0.108046         -0.039968          -0.03639
# tBodyAcc-mean()-Z            -0.056677         -0.143397         -0.167651
# tBodyAcc-std()-X             -0.230796         -0.230396         -0.176954
# tBodyAcc-std()-Y             -0.140521         -0.133669         -0.050147
# ...                                ...               ...               ...
# angle(X,gravityMean)         -0.830575         -0.799426         -0.787935
# angle(Y,gravityMean)          0.213174           0.23549           0.24449
# angle(Z,gravityMean)         -0.005105         -0.001647          0.009538
# subject                             30                30                30
# Activity              WALKING_UPSTAIRS  WALKING_UPSTAIRS  WALKING_UPSTAIRS
#
#                                   7345              7346              7347  \
# tBodyAcc-mean()-X             0.207861          0.237966          0.299665
# tBodyAcc-mean()-Y             0.063423         -0.001088         -0.057193
# tBodyAcc-mean()-Z            -0.220567         -0.148326         -0.181233
# tBodyAcc-std()-X             -0.244758         -0.218949         -0.195387
# tBodyAcc-std()-Y             -0.032159         -0.012927          0.039905
# ...                                ...               ...               ...
# angle(X,gravityMean)         -0.780362         -0.797272         -0.791883
# angle(Y,gravityMean)          0.249624          0.234996          0.238604
# angle(Z,gravityMean)          0.027878          0.048907          0.049819
# subject                             30                30                30
# Activity              WALKING_UPSTAIRS  WALKING_UPSTAIRS  WALKING_UPSTAIRS
#
#                                   7348              7349              7350  \
# tBodyAcc-mean()-X             0.273853          0.273387          0.289654
# tBodyAcc-mean()-Y            -0.007749         -0.017011         -0.018843
# tBodyAcc-mean()-Z            -0.147468         -0.045022         -0.158281
# tBodyAcc-std()-X             -0.235309         -0.218218         -0.219139
# tBodyAcc-std()-Y              0.004816         -0.103822         -0.111412
# ...                                ...               ...               ...
# angle(X,gravityMean)          -0.77184         -0.779133         -0.785181
# angle(Y,gravityMean)          0.252676          0.249145          0.246432
# angle(Z,gravityMean)          0.050053          0.040811          0.025339
# subject                             30                30                30
# Activity              WALKING_UPSTAIRS  WALKING_UPSTAIRS  WALKING_UPSTAIRS
#
#                                   7351
# tBodyAcc-mean()-X             0.351503
# tBodyAcc-mean()-Y            -0.012423
# tBodyAcc-mean()-Z            -0.203867
# tBodyAcc-std()-X              -0.26927
# tBodyAcc-std()-Y             -0.087212
# ...                                ...
# angle(X,gravityMean)         -0.783267
# angle(Y,gravityMean)          0.246809
# angle(Z,gravityMean)          0.036695
# subject                             30
# Activity              WALKING_UPSTAIRS
#
# [563 rows x 7352 columns]

# %%
print(df.Activity.unique())
print("----------------------------------------")
print(df.Activity.value_counts())
# Out:
# ['STANDING' 'SITTING' 'LAYING' 'WALKING' 'WALKING_DOWNSTAIRS'
#  'WALKING_UPSTAIRS']
# ----------------------------------------
# LAYING                1407
# STANDING              1374
# SITTING               1286
# WALKING               1226
# WALKING_UPSTAIRS      1073
# WALKING_DOWNSTAIRS     986
# Name: Activity, dtype: int64

# %%
sns.set(rc={'figure.figsize':(13,6)})
fig = sns.countplot(x = "Activity" , data = df)
plt.xlabel("Activity")
plt.ylabel("Count")
plt.title("Activity Count")
plt.grid(True)
plt.show(fig)

# %%
pd.crosstab(df.subject, df.Activity, margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style  type="text/css" >
# #T_84a71_row0_col0,#T_84a71_row0_col1,#T_84a71_row2_col0,#T_84a71_row2_col1,#T_84a71_row2_col6,#T_84a71_row4_col0,#T_84a71_row4_col1,#T_84a71_row4_col6,#T_84a71_row5_col0,#T_84a71_row5_col1,#T_84a71_row5_col3,#T_84a71_row5_col4,#T_84a71_row5_col5,#T_84a71_row5_col6,#T_84a71_row6_col2,#T_84a71_row7_col0,#T_84a71_row11_col4,#T_84a71_row11_col5,#T_84a71_row13_col3,#T_84a71_row13_col4,#T_84a71_row13_col5{
#             background-color:  #ffff00;
#             color:  #000000;
#         }#T_84a71_row0_col2,#T_84a71_row1_col1,#T_84a71_row2_col2,#T_84a71_row2_col5,#T_84a71_row3_col0,#T_84a71_row3_col2,#T_84a71_row3_col6,#T_84a71_row4_col2,#T_84a71_row5_col2,#T_84a71_row6_col0,#T_84a71_row6_col1,#T_84a71_row6_col6,#T_84a71_row7_col6,#T_84a71_row8_col2,#T_84a71_row8_col3,#T_84a71_row8_col4,#T_84a71_row8_col5,#T_84a71_row8_col6,#T_84a71_row9_col3,#T_84a71_row10_col5,#T_84a71_row11_col3,#T_84a71_row12_col3,#T_84a71_row12_col5,#T_84a71_row13_col6,#T_84a71_row18_col3,#T_84a71_row19_col3{
#             background-color:  #fffe00;
#             color:  #000000;
#         }#T_84a71_row0_col3{
#             background-color:  #fff500;
#             color:  #000000;
#         }#T_84a71_row0_col4,#T_84a71_row0_col5,#T_84a71_row1_col4,#T_84a71_row3_col4,#T_84a71_row6_col5,#T_84a71_row7_col5,#T_84a71_row8_col1,#T_84a71_row9_col0,#T_84a71_row9_col6,#T_84a71_row10_col0,#T_84a71_row10_col3,#T_84a71_row10_col6,#T_84a71_row13_col1,#T_84a71_row13_col2,#T_84a71_row14_col6,#T_84a71_row16_col4,#T_84a71_row16_col5,#T_84a71_row17_col6,#T_84a71_row18_col6,#T_84a71_row19_col0,#T_84a71_row19_col1,#T_84a71_row19_col2,#T_84a71_row19_col4,#T_84a71_row20_col0,#T_84a71_row20_col1,#T_84a71_row20_col6{
#             background-color:  #fffc00;
#             color:  #000000;
#         }#T_84a71_row0_col6,#T_84a71_row1_col0,#T_84a71_row1_col2,#T_84a71_row1_col3,#T_84a71_row1_col6,#T_84a71_row2_col3,#T_84a71_row2_col4,#T_84a71_row3_col1,#T_84a71_row3_col3,#T_84a71_row3_col5,#T_84a71_row4_col3,#T_84a71_row4_col4,#T_84a71_row4_col5,#T_84a71_row6_col3,#T_84a71_row6_col4,#T_84a71_row7_col1,#T_84a71_row7_col2,#T_84a71_row7_col3,#T_84a71_row7_col4,#T_84a71_row9_col4,#T_84a71_row9_col5,#T_84a71_row10_col4,#T_84a71_row11_col6,#T_84a71_row12_col4,#T_84a71_row14_col3,#T_84a71_row14_col5,#T_84a71_row16_col3,#T_84a71_row17_col3,#T_84a71_row17_col4,#T_84a71_row17_col5,#T_84a71_row18_col4,#T_84a71_row18_col5,#T_84a71_row19_col5,#T_84a71_row19_col6,#T_84a71_row20_col2{
#             background-color:  #fffd00;
#             color:  #000000;
#         }#T_84a71_row1_col5,#T_84a71_row8_col0,#T_84a71_row10_col1,#T_84a71_row12_col6,#T_84a71_row13_col0,#T_84a71_row14_col0,#T_84a71_row14_col1,#T_84a71_row14_col2,#T_84a71_row14_col4,#T_84a71_row15_col0,#T_84a71_row15_col1,#T_84a71_row15_col6,#T_84a71_row16_col0,#T_84a71_row16_col6,#T_84a71_row17_col0,#T_84a71_row20_col3{
#             background-color:  #fffb00;
#             color:  #000000;
#         }#T_84a71_row9_col1,#T_84a71_row9_col2,#T_84a71_row10_col2,#T_84a71_row11_col1,#T_84a71_row11_col2,#T_84a71_row15_col2,#T_84a71_row15_col4,#T_84a71_row16_col2,#T_84a71_row17_col1,#T_84a71_row18_col0,#T_84a71_row18_col1{
#             background-color:  #fffa00;
#             color:  #000000;
#         }#T_84a71_row11_col0,#T_84a71_row15_col3,#T_84a71_row15_col5,#T_84a71_row17_col2,#T_84a71_row18_col2,#T_84a71_row20_col5{
#             background-color:  #fff900;
#             color:  #000000;
#         }#T_84a71_row12_col0,#T_84a71_row16_col1,#T_84a71_row20_col4{
#             background-color:  #fff800;
#             color:  #000000;
#         }#T_84a71_row12_col1,#T_84a71_row12_col2{
#             background-color:  #fff700;
#             color:  #000000;
#         }#T_84a71_row21_col0,#T_84a71_row21_col1,#T_84a71_row21_col2,#T_84a71_row21_col3,#T_84a71_row21_col4,#T_84a71_row21_col5,#T_84a71_row21_col6{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }</style><table id="T_84a71_" ><thead>    <tr>        <th class="index_name level0" >Activity</th>        <th class="col_heading level0 col0" >LAYING</th>        <th class="col_heading level0 col1" >SITTING</th>        <th class="col_heading level0 col2" >STANDING</th>        <th class="col_heading level0 col3" >WALKING</th>        <th class="col_heading level0 col4" >WALKING_DOWNSTAIRS</th>        <th class="col_heading level0 col5" >WALKING_UPSTAIRS</th>        <th class="col_heading level0 col6" >All</th>    </tr>    <tr>        <th class="index_name level0" >subject</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_84a71_level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_84a71_row0_col0" class="data row0 col0" >50</td>
#                         <td id="T_84a71_row0_col1" class="data row0 col1" >47</td>
#                         <td id="T_84a71_row0_col2" class="data row0 col2" >53</td>
#                         <td id="T_84a71_row0_col3" class="data row0 col3" >95</td>
#                         <td id="T_84a71_row0_col4" class="data row0 col4" >49</td>
#                         <td id="T_84a71_row0_col5" class="data row0 col5" >53</td>
#                         <td id="T_84a71_row0_col6" class="data row0 col6" >347</td>
#             </tr>
#             <tr>
#                         <th id="T_84a71_level0_row1" class="row_heading level0 row1" >3</th>
#                         <td id="T_84a71_row1_col0" class="data row1 col0" >62</td>
#                         <td id="T_84a71_row1_col1" class="data row1 col1" >52</td>
#                         <td id="T_84a71_row1_col2" class="data row1 col2" >61</td>
#                         <td id="T_84a71_row1_col3" class="data row1 col3" >58</td>
#                         <td id="T_84a71_row1_col4" class="data row1 col4" >49</td>
#                         <td id="T_84a71_row1_col5" class="data row1 col5" >59</td>
#                         <td id="T_84a71_row1_col6" class="data row1 col6" >341</td>
#             </tr>
#             <tr>
#                         <th id="T_84a71_level0_row2" class="row_heading level0 row2" >5</th>
#                         <td id="T_84a71_row2_col0" class="data row2 col0" >52</td>
#                         <td id="T_84a71_row2_col1" class="data row2 col1" >44</td>
#                         <td id="T_84a71_row2_col2" class="data row2 col2" >56</td>
#                         <td id="T_84a71_row2_col3" class="data row2 col3" >56</td>
#                         <td id="T_84a71_row2_col4" class="data row2 col4" >47</td>
#                         <td id="T_84a71_row2_col5" class="data row2 col5" >47</td>
#                         <td id="T_84a71_row2_col6" class="data row2 col6" >302</td>
#             </tr>
#             <tr>
#                         <th id="T_84a71_level0_row3" class="row_heading level0 row3" >6</th>
#                         <td id="T_84a71_row3_col0" class="data row3 col0" >57</td>
#                         <td id="T_84a71_row3_col1" class="data row3 col1" >55</td>
#                         <td id="T_84a71_row3_col2" class="data row3 col2" >57</td>
#                         <td id="T_84a71_row3_col3" class="data row3 col3" >57</td>
#                         <td id="T_84a71_row3_col4" class="data row3 col4" >48</td>
#                         <td id="T_84a71_row3_col5" class="data row3 col5" >51</td>
#                         <td id="T_84a71_row3_col6" class="data row3 col6" >325</td>
#             </tr>
#             <tr>
#                         <th id="T_84a71_level0_row4" class="row_heading level0 row4" >7</th>
#                         <td id="T_84a71_row4_col0" class="data row4 col0" >52</td>
#                         <td id="T_84a71_row4_col1" class="data row4 col1" >48</td>
#                         <td id="T_84a71_row4_col2" class="data row4 col2" >53</td>
#                         <td id="T_84a71_row4_col3" class="data

# %%
print(df.shape , test.shape)
# Out:
# (7352, 563) (2947, 563)

# %%
df.columns
# Out:
# Index(['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z',
#        'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z',
#        'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z',
#        'tBodyAcc-max()-X',
#        ...
#        'fBodyBodyGyroJerkMag-kurtosis()', 'angle(tBodyAccMean,gravity)',
#        'angle(tBodyAccJerkMean),gravityMean)',
#        'angle(tBodyGyroMean,gravityMean)',
#        'angle(tBodyGyroJerkMean,gravityMean)', 'angle(X,gravityMean)',
#        'angle(Y,gravityMean)', 'angle(Z,gravityMean)', 'subject', 'Activity'],
#       dtype='object', length=563)

# %% [markdown]
# ## Now some visualizations for feature distribution in space.

# %%
sns.set(rc={'figure.figsize':(15,7)})
colours = ["maroon","coral","darkorchid","goldenrod","purple","darkgreen","darkviolet","saddlebrown","aqua","olive"]
index = -1
for i in df.columns[0:10]:
    index = index + 1
    fig = sns.kdeplot(df[i] , shade=True, color=colours[index])
plt.xlabel("Features")
plt.ylabel("Value")
plt.title("Feature Distribution")
plt.grid(True)
plt.show(fig)

# %%
sns.set(rc={'figure.figsize':(15,7)})
colours = ["maroon","coral","darkorchid","goldenrod","purple","darkgreen","darkviolet","saddlebrown","aqua","olive"]
index = -1
for i in df.columns[10:20]:
    index = index + 1
    ax1 = sns.kdeplot(df[i] , shade=True, color=colours[index])
plt.xlabel("Features")
plt.ylabel("Value")
plt.title("Feature Distribution")
plt.grid(True)
plt.show(fig)

# %%
sns.set(rc={'figure.figsize':(15,7)})
colours = ["maroon","coral","darkorchid","goldenrod","purple","darkgreen","darkviolet","saddlebrown","aqua","olive"]
index = -1
for i in df.columns[20:30]:
    index = index + 1
    ax1 = sns.kdeplot(df[i] , shade=True, color=colours[index])
plt.xlabel("Features")
plt.ylabel("Value")
plt.title("Feature Distribution")
plt.grid(True)
plt.show(fig)

# %%
sns.set(rc={'figure.figsize':(15,7)})
colours = ["maroon","coral","darkorchid","goldenrod","purple","darkgreen","darkviolet","saddlebrown","aqua","olive"]
index = -1
for i in df.columns[30:40]:
    index = index + 1
    ax1 = sns.kdeplot(df[i] , shade=True, color=colours[index])
plt.xlabel("Features")
plt.ylabel("Value")
plt.title("Feature Distribution")
plt.grid(True)
plt.show(fig)

# %%
sns.set(rc={'figure.figsize':(15,7)})
colours = ["maroon","coral","darkorchid","goldenrod","purple","darkgreen","darkviolet","saddlebrown","aqua","olive"]
index = -1
for i in df.columns[40:50]:
    index = index + 1
    ax1 = sns.kdeplot(df[i] , shade=True, color=colours[index])
plt.xlabel("Features")
plt.ylabel("Value")
plt.title("Feature Distribution")
plt.grid(True)
plt.show(fig)

# %%
sns.set(rc={'figure.figsize':(15,10)})
plt.subplot(221)
fig1 = sns.stripplot(x='Activity', y= df.loc[df['Activity']=="STANDING"].iloc[:,10], data= df.loc[df['Activity']=="STANDING"], jitter=True)
plt.title("Feature Distribution")
plt.grid(True)
plt.show(fig1)
plt.subplot(224)
fig2 = sns.stripplot(x='Activity', y= df.loc[df['Activity']=="STANDING"].iloc[:,11], data= df.loc[df['Activity']=="STANDING"], jitter=True)
plt.title("Feature Distribution")
plt.grid(True)
plt.show(fig2)
plt.subplot(223)
fig2 = sns.stripplot(x='Activity', y= df.loc[df['Activity']=="STANDING"].iloc[:,12], data= df.loc[df['Activity']=="STANDING"], jitter=True)
plt.title("Feature Distribution")
plt.grid(True)
plt.show(fig2)
plt.subplot(222)
fig2 = sns.stripplot(x='Activity', y= df.loc[df['Activity']=="STANDING"].iloc[:,13], data= df.loc[df['Activity']=="STANDING"], jitter=True)
plt.title("Feature Distribution")
plt.grid(True)
plt.show(fig2)

# %%
sns.set(rc={'figure.figsize':(15,5)})
fig1 = sns.stripplot(x='Activity', y= df.loc[df['subject']==15].iloc[:,7], data= df.loc[df['subject']==15], jitter=True)
plt.title("Feature Distribution")
plt.grid(True)
plt.show(fig1)

# %% [markdown]
# **Feature Scaling**

# %% [markdown]
# **Pre-processing and data preparation to feed data into Artificial Neural Network.**

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(df.iloc[:,0:562])
mat_train = scaler.transform(df.iloc[:,0:562])
print(mat_train)
# Out:
# [[0.64429225 0.48985291 0.43354743 ... 0.79825103 0.47068654 0.        ]
#  [0.63920942 0.49179472 0.4382399  ... 0.79848665 0.47284164 0.        ]
#  [0.63982653 0.49026642 0.44326915 ... 0.79872236 0.47544109 0.        ]
#  ...
#  [0.63669369 0.49149469 0.47748909 ... 0.84506893 0.52040559 1.        ]
#  [0.64482708 0.49057848 0.42085971 ... 0.84323381 0.51266974 1.        ]
#  [0.67575173 0.49378844 0.39806642 ... 0.84348837 0.51834742 1.        ]]

# %%
scaler = MinMaxScaler()
scaler.fit(test.iloc[:,0:562])
mat_test = scaler.transform(test.iloc[:,0:562])
print(mat_test)
# Out:
# [[0.6718788  0.55764282 0.52464834 ... 0.62209457 0.46362736 0.        ]
#  [0.69470427 0.57426358 0.42707858 ... 0.62446791 0.45014396 0.        ]
#  [0.68636345 0.55310221 0.42794829 ... 0.62380956 0.45251181 0.        ]
#  ...
#  [0.74529355 0.64526771 0.43015674 ... 0.62088108 0.58803909 1.        ]
#  [0.65638384 0.62620241 0.44817885 ... 0.61581385 0.59135763 1.        ]
#  [0.58994885 0.56560474 0.41032069 ... 0.61537208 0.59163879 1.        ]]

# %%
temp = []
for i in df.Activity:
    if i == "WALKING": temp.append(0)
    if i == "WALKING_UPSTAIRS": temp.append(1)
    if i == "WALKING_DOWNSTAIRS": temp.append(2)
    if i == "SITTING": temp.append(3)
    if i == "STANDING": temp.append(4)
    if i == "LAYING": temp.append(5)
df["n_Activity"] = temp

# %%
temp = []
for i in test.Activity:
    if i == "WALKING": temp.append(0)
    if i == "WALKING_UPSTAIRS": temp.append(1)
    if i == "WALKING_DOWNSTAIRS": temp.append(2)
    if i == "SITTING": temp.append(3)
    if i == "STANDING": temp.append(4)
    if i == "LAYING": temp.append(5)
test["n_Activity"] = temp

# %%
df.drop(["Activity"] , axis = 1 , inplace = True)

# %%
test.drop(["Activity"] , axis = 1 , inplace = True)

# %%
from keras.utils import to_categorical
y_train = to_categorical(df.n_Activity , num_classes=6)
y_test = to_categorical(test.n_Activity , num_classes=6)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8936/2209230427.py in <module>
# ----> 1 from keras.utils import to_categorical
#       2 y_train = to_categorical(df.n_Activity , num_classes=6)
#       3 y_test = to_categorical(test.n_Activity , num_classes=6)
#
# ModuleNotFoundError: No module named 'keras'

# %%
X_train = mat_train 
X_test = mat_test

# %% [markdown]
# **Though it is a 562 feature vector which is large enough and might cause overfitting while training.**

# %% [markdown]
# **Also gone for feature selection using extra tree classifier and l1 selection , but the results were slightly better with all features only when I tune the hyperparameters of the model to its almost utmost level which took some time.**

# %% [markdown]
# **Having less features will also take less time to train but in this case manual selection of features reagrding context can't be done and the other approach has already been discussed above.**

# %%
print(X_train.shape , y_train.shape)
print(X_test.shape , y_test.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8936/3981322302.py in <module>
# ----> 1 print(X_train.shape , y_train.shape)
#       2 print(X_test.shape , y_test.shape)
#
# NameError: name 'X_train' is not defined

# %% [markdown]
# **Taking necessary callbacks of checkpointing and learning rate reducer.**

# %%
filepath="HAR_weights.hdf5"
from keras.callbacks import ReduceLROnPlateau , ModelCheckpoint

lr_reduce = ReduceLROnPlateau(monitor='val_acc', factor=0.1, epsilon=0.0001, patience=1, verbose=1)
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8936/2417594944.py in <module>
#       1 filepath="HAR_weights.hdf5"
# ----> 2 from keras.callbacks import ReduceLROnPlateau , ModelCheckpoint
#       3
#       4 lr_reduce = ReduceLROnPlateau(monitor='val_acc', factor=0.1, epsilon=0.0001, patience=1, verbose=1)
#       5 checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
#
# ModuleNotFoundError: No module named 'keras'

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout , BatchNormalization
from sklearn.model_selection import train_test_split
from keras.utils import np_utils
from keras.optimizers import RMSprop, Adam
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8936/3232224384.py in <module>
# ----> 1 from keras.models import Sequential
#       2 from keras.layers import Dense, Dropout , BatchNormalization
#       3 from sklearn.model_selection import train_test_split
#       4 from keras.utils import np_utils
#       5 from keras.optimizers import RMSprop, Adam
#
# ModuleNotFoundError: No module named 'keras'

# %% [markdown]
# **The below model architecture is the best I could come up with after repeated tuning and changes in network architecture.**

# %% [markdown]
# **At last, the BatchNormalization layer did some good to slightly boost the accuracy.**

# %% [markdown]
# **Taken special care of learning rate and batch_size to which the model is very sensitive and have to repeatedly adjust them in order to get one of the best result in front.**

# %%
model = Sequential()

model.add(Dense(64, input_dim=X_train.shape[1] , activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(128, activation='relu'))
model.add(Dense(196, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(6, activation='sigmoid'))

model.compile(optimizer = Adam(lr = 0.0005),loss='categorical_crossentropy', metrics=['accuracy'])
print(model.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8936/4193953210.py in <module>
# ----> 1 model = Sequential()
#       2
#       3 model.add(Dense(64, input_dim=X_train.shape[1] , activation='relu'))
#       4 model.add(Dense(64, activation='relu'))
#       5 model.add(BatchNormalization())
#
# NameError: name 'Sequential' is not defined

# %% [markdown]
# ## Finally, the best model was checkpointed and got a validation loss of 0.0562 and a validation accuracy of 97.98% or ~98%.

# %%
history = model.fit(X_train, y_train , epochs=22 , batch_size = 256 , validation_data=(X_test, y_test) , callbacks=[checkpoint,lr_reduce])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8936/1621183486.py in <module>
# ----> 1 history = model.fit(X_train, y_train , epochs=22 , batch_size = 256 , validation_data=(X_test, y_test) , callbacks=[checkpoint,lr_reduce])
#
# NameError: name 'model' is not defined

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 10, 4
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8936/290958413.py in <module>
#       1 from pylab import rcParams
#       2 rcParams['figure.figsize'] = 10, 4
# ----> 3 plt.plot(history.history['acc'])
#       4 plt.plot(history.history['val_acc'])
#       5 plt.title('model accuracy')
#
# NameError: name 'history' is not defined

# %%
from sklearn.metrics import confusion_matrix
model.load_weights("HAR_weights.hdf5")
pred = model.predict(X_test)
pred = np.argmax(pred,axis = 1) 
y_true = np.argmax(y_test,axis = 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8936/458780984.py in <module>
#       1 from sklearn.metrics import confusion_matrix
# ----> 2 model.load_weights("HAR_weights.hdf5")
#       3 pred = model.predict(X_test)
#       4 pred = np.argmax(pred,axis = 1)
#       5 y_true = np.argmax(y_test,axis = 1)
#
# NameError: name 'model' is not defined

# %% [markdown]
# ## The confusion matrix is plotted to get better insight of model performance using mlxted to refrain from extra code via scikit.

# %% [markdown]
# ## The model performance is evident from the diagonal concentration of the values.**

# %%
CM = confusion_matrix(y_true, pred)
from mlxtend.plotting import plot_confusion_matrix
fig, ax = plot_confusion_matrix(conf_mat=CM ,  figsize=(10, 5))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8936/3615673975.py in <module>
# ----> 1 CM = confusion_matrix(y_true, pred)
#       2 from mlxtend.plotting import plot_confusion_matrix
#       3 fig, ax = plot_confusion_matrix(conf_mat=CM ,  figsize=(10, 5))
#       4 plt.show()
#
# NameError: name 'y_true' is not defined

# %% [markdown]
# ## Precision - 95% , Recall - 94% and f1-score of 94%.

# %%
from sklearn.metrics import classification_report , accuracy_score
print(classification_report(y_true, pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8936/1469172989.py in <module>
#       1 from sklearn.metrics import classification_report , accuracy_score
# ----> 2 print(classification_report(y_true, pred))
#
# NameError: name 'y_true' is not defined

# %% [markdown]
# **Exporting predictions.**

# %%
d = { "Index":np.arange(2947) , "Activity":pred }
final = pd.DataFrame(d)
final.to_csv( 'human_activity_predictions.csv' , index = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8936/3618199477.py in <module>
# ----> 1 d = { "Index":np.arange(2947) , "Activity":pred }
#       2 final = pd.DataFrame(d)
#       3 final.to_csv( 'human_activity_predictions.csv' , index = False)
#
# NameError: name 'pred' is not defined
